# %%
from dotenv import load_dotenv
load_dotenv()

import os

client_id = os.environ.get("SPOTIPY_CLIENT_ID")
client_secret = os.environ.get("SPOTIPY_CLIENT_SECRET")

# %%
print(client_id)
print(client_secret)
# Out:
# cf861f2e4e254335be41c0f7821580d1
# ddad50f6eb3e4e02a3730ed894b5e833

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
billie = 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())
#SpotifyClientCredentials(client_id='YOUR ID', client_secret='YOUR SECRET')

results = spotify.artist_top_tracks(billie)
for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
print(results.keys())
# Out:
# track    : What Was I Made For? [From The Motion Picture "Barbie"]
# track    : lovely (with Khalid)
# track    : ocean eyes
# track    : when the party's over
# track    : Happier Than Ever
# track    : hotline (edit)
# track    : everything i wanted
# track    : TV
# track    : Bored
# track    : bad guy
# dict_keys(['tracks'])

# %%
billie_df = pd.DataFrame.from_dict(results["tracks"])
billie_df
# Out:
#                                                album  \
# 0  {'album_type': 'single', 'artists': [{'externa...
# 1  {'album_type': 'single', 'artists': [{'externa...
# 2  {'album_type': 'single', 'artists': [{'externa...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'single', 'artists': [{'externa...
# 6  {'album_type': 'single', 'artists': [{'externa...
# 7  {'album_type': 'single', 'artists': [{'externa...
# 8  {'album_type': 'single', 'artists': [{'externa...
# 9  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# ...

# %%
billie_df = billie_df.filter(items =['index', 'name', 'duration_ms', 'popularity'])
billie_df
# Out:
#                                                 name  duration_ms  popularity
# 0  What Was I Made For? [From The Motion Picture ...       222369          94
# 1                               lovely (with Khalid)       200185          90
# 2                                         ocean eyes       200560          75
# 3                              when the party's over       196077          87
# 4                                  Happier Than Ever       298899          86
# 5                                     hotline (edit)        60719          86
# 6                                everything i wanted       245425          85
# 7                                                 TV       281380          85
# 8                                              Bored       180933          84
# 9                                            bad guy       194087          84

# %%
plt.scatter(x=billie_df['duration_ms'], y=billie_df['popularity'], cmap="viridis")
plt.colorbar()
# Out:
# /tmp/ipykernel_559/1524088393.py:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x=billie_df['duration_ms'], y=billie_df['popularity'], cmap="viridis")

# %%
np.corrcoef(billie_df['duration_ms'], billie_df['popularity'])
# Out:
# array([[1.        , 0.04413777],
#        [0.04413777, 1.        ]])
